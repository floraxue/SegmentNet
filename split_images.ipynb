# %%
from skimage.io import imread, imsave, imshow
from skimage import img_as_ubyte
import matplotlib
# %matplotlib inline
import os
from os.path import join

# %%
image_path = '../data/dataset_1/raw_image_100/{:04d}.tif'.format(1)

print(image_path)
# Out:
# ../data/dataset_1/raw_image_100/0001.tif

# %%
x_test = imread(image_path)
x_test = img_as_ubyte(x_test)
imshow(x_test)
x_test.shape
# Out:
# /Users/floraxue/anaconda3/lib/python3.4/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# (2560, 2560)

# %%
target_size = 256
stride = 64
num_crops = (x_test.shape[0] - target_size) / stride + 1   # num_crops per axis. total_crops = num_crops**2
print(num_crops)
num_crops = int(num_crops)
# Out:
# 37.0

# %%
# [i_start, i_end)
save_dir = '../data/dataset_1/raw_crop_image_100/{:04d}/'.format(1)
os.makedirs(save_dir, exist_ok=True)
for row in range(num_crops):
    for col in range(num_crops):
        jstart, jend = col * stride, col * stride + target_size
        istart, iend = row * stride, row * stride + target_size
        curr_crop = x_test[istart:iend, jstart:jend].copy()
        imsave(join(save_dir, 'row_{}_col_{}_crop.tif'.format(row, col)), curr_crop)
# Out:
# /Users/floraxue/anaconda3/lib/python3.4/site-packages/skimage/io/_io.py:132: UserWarning: ../data/dataset_1/raw_image_100/0001/row_0_col_0_crop.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Users/floraxue/anaconda3/lib/python3.4/site-packages/skimage/io/_io.py:132: UserWarning: ../data/dataset_1/raw_image_100/0001/row_0_col_1_crop.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Users/floraxue/anaconda3/lib/python3.4/site-packages/skimage/io/_io.py:132: UserWarning: ../data/dataset_1/raw_image_100/0001/row_0_col_2_crop.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# /Users/floraxue/anaconda3/lib/python3.4/site-packages/skimage/io/_io.py:132: UserWarning: ../data/dataset_1/raw_image_100/0001/row_0_col_3_crop.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)
# ...

# %%
##################### Formal code below #####################
# Configurations
input_img_dir = '../data/dataset_1/raw_image_100/'
all_save_dir = '../data/dataset_1/raw_crop_image_100/'
os.makedirs(save_dir, exist_ok=True)
input_shape = 2560
target_size = 256
stride = 64
num_crops = (input_shape - target_size) / stride + 1   # num_crops per axis. total_crops = num_crops**2
print("Num_crops", num_crops)
num_crops = int(num_crops)

import warnings
# with warnings.catch_warnings():
#     warnings.simplefilter("ignore")
#     img_as_ubyte(image)
    
for i in range(1, 101):
    
    image_path = join(input_img_dir, '{:04d}.tif'.format(i))
    print("Now saving " + image_path)
    img = imread(image_path)
    img = img_as_ubyte(img)
    img_save_dir = join(save_dir, '{:04d}'.format(i))
    os.makedirs(img_save_dir, exist_ok=True)
    
    for row in range(num_crops):
        for col in range(num_crops):
            jstart, jend = col * stride, col * stride + target_size
            istart, iend = row * stride, row * stride + target_size
            curr_crop = img[istart:iend, jstart:jend].copy()
            save_path = join(img_save_dir, 'row_{}_col_{}_crop.tif'.format(row, col))
            with warnings.catch_warnings():
                warnings.simplefilter("ignore")
                imsave(save_path, curr_crop)
# Out:
# Num_crops 37.0
# Now saving ../data/dataset_1/raw_image_100/0001.tif
# Now saving ../data/dataset_1/raw_image_100/0002.tif
# Now saving ../data/dataset_1/raw_image_100/0003.tif
# Now saving ../data/dataset_1/raw_image_100/0004.tif
# Now saving ../data/dataset_1/raw_image_100/0005.tif
# Now saving ../data/dataset_1/raw_image_100/0006.tif
# Now saving ../data/dataset_1/raw_image_100/0007.tif
# Now saving ../data/dataset_1/raw_image_100/0008.tif
# Now saving ../data/dataset_1/raw_image_100/0009.tif
# Now saving ../data/dataset_1/raw_image_100/0010.tif
# Now saving ../data/dataset_1/raw_image_100/0011.tif
# Now saving ../data/dataset_1/raw_image_100/0012.tif
# Now saving ../data/dataset_1/raw_image_100/0013.tif
# Now saving ../data/dataset_1/raw_image_100/0014.tif
# Now saving ../data/dataset_1/raw_image_100/0015.tif
# Now saving ../data/dataset_1/raw_image_100/0016.tif
# Now saving ../data/dataset_1/raw_image_100/0017.tif
# Now saving ../data/dataset_1/raw_image_100/0018.tif
# ...
